# %% [markdown]
# # 🚀 LLM in Python - From Simple to Complex
#
# This notebook walks through practical Groq API examples, progressively building in complexity.
#
# | # | Example | Difficulty |
# |---|---------|------------|
# | 1 | Setup & Basic Chat | ⭐ |
# | 2 | System Prompts & Personas | ⭐⭐ |
# | 3 | Prompt Chaining (Basic) | ⭐⭐ |
# | 4 | Prompt Chaining (Advanced Workflow) | ⭐⭐⭐ |
# | 5 | Prompt Chaining (Real-Life Support Workflow) | ⭐⭐⭐⭐ |
# | 6 | Prompt Chaining (Stock Market Workflow) | ⭐⭐⭐⭐ |
# | 7 | Streaming Responses | ⭐⭐ |
# | 8 | Multi-turn Conversations | ⭐⭐⭐ |
# | 9 | Structured JSON Output | ⭐⭐⭐ |
# | 10 | Sentiment Analysis Pipeline | ⭐⭐⭐ |
# | 11 | RAG — Retrieval-Augmented Generation | ⭐⭐⭐⭐ |
# | 12 | Async Batch Processing | ⭐⭐⭐⭐ |
# | 13 | Prompt Chaining & Summarization | ⭐⭐⭐ |
# | 14 | Interactive Chatbot UI | ⭐⭐⭐⭐ |
# | 15 | CSV / Data Analysis Agent | ⭐⭐⭐⭐⭐ |

# %% [markdown]
# ## 🔧 Setup — Install & Configure

# %%
# !pip install groq faiss-cpu sentence-transformers ipywidgets -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.7/139.7 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 31.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 40.1 MB/s eta 0:00:00

# %%
import os
from google.colab import userdata

# Option A: Store your key in Colab Secrets (recommended)
# Go to the key icon in the left sidebar and add GROQ_API_KEY
try:
    GROQ_API_KEY = userdata.get('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')
    print('Loaded API key from Colab Secrets')
except Exception:
    GROQ_API_KEY = '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'  # Replace with your key
    print('Using hardcoded key - prefer Colab Secrets for security')

os.environ['GROQ_API_KEY'] = GROQ_API_KEY
# Out:
# Using hardcoded key - prefer Colab Secrets for security

# %%
from groq import Groq

client = Groq(api_key=GROQ_API_KEY)

MODELS = {
    'fast':     'llama-3.1-8b-instant',
    'balanced': 'llama-3.3-70b-versatile',
    'code':     'qwen-2.5-coder-32b',
}

print('Groq client ready!')
print('Models:', list(MODELS.keys()))
# Out:
# Groq client ready!
# Models: ['fast', 'balanced', 'code']

# %% [markdown]
# ---
# ## Example 1 - Basic Chat Completion

# %%
response = client.chat.completions.create(
    model=MODELS['fast'],
    messages=[
        {"role": "user", "content": "What is Groq and why is it so fast?"}
    ]
)

print(response.choices[0].message.content)
print(f"\nTokens used: {response.usage.total_tokens}")
print(f"Speed: {response.usage.completion_tokens / response.usage.completion_time:.0f} tokens/sec")
# Out:
# Groq (formerly known as Groq Inc.) is a US-based company that specializes in designing high-performance AI hardware, focusing particularly on accelerators and deep learning chips. The key innovation behind Groq's technology is its ability to dramatically accelerate machine learning and AI workloads.
#
# Groq's acceleration comes from the architecture of their chips. Unlike traditional GPUs (Graphics Processing Units) and TPUs (Tensor Processing Units), which are optimized for specific tasks, Groq's design takes a different approach. They employ a concept called "domain-specific architecture," which means their chips are specifically tailored to handle a wide range of deep learning workloads more efficiently.
#
# Several reasons contribute to Groq's performance:
#
# 1. **Customized silicon design**: By creating custom silicon, Groq can optimize the hardware architecture to meet the specific requirements of AI workloads. This design enables more efficient execution of certain computations and a lower power consumption profile.
# 2. **Highly scalable parallelism**: Groq's architecture is designed to support massive parallelism, allowing it to take advantage of the massive amount of data in modern AI workloads. This scalability enables the simultaneous processing of thousands of neural network operations, significantly increasing performance.
# 3. **Efficient memory design**: Groq's chips are designed to use memory more effectively, with features such as optimized memory access patterns and reduced latency. This efficient memory layout enables faster data transfer and computation.
# 4. **Sustained peak performance**: Unlike other accelerators that may peak at high performance but then slow down as they are utilized for longer periods of time, Groq's chips maintain their peak performance levels for extended periods of usage.
# 5. **Flexibility**: Groq's accelerators can handle a wide range of deep learning frameworks and models, allowing users to easily integrate them into existing workflows.
#
# In conclusion, Groq's unique approach to designing high-performance AI hardware, combined with its domain-specific architecture, scalability, and efficient memory design, makes it well-suited for the demands of modern AI workloads.
#
# Tokens used: 453
# Speed: 337 tokens/sec

# %% [markdown]
# ---
# ## Example 2 - System Prompts & Personas

# %%
def chat_with_persona(persona_prompt, user_message, model=None):
    model = model or MODELS['fast']
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": persona_prompt},
            {"role": "user",   "content": user_message}
        ],
        temperature=0.7,
        max_tokens=512
    )
    return response.choices[0].message.content


socratic = """
You are a Socratic teacher. Never give direct answers.
Guide the student with thoughtful questions only. Keep responses under 80 words.
"""
print("Socratic Teacher:")
print(chat_with_persona(socratic, "Why does the sky appear blue?"))

print("\n" + "-"*60 + "\n")

pirate_chef = """
You are a salty old pirate who is also a Michelin-star chef.
Speak in pirate dialect but give genuine, expert cooking advice.
"""
print("Pirate Chef:")
print(chat_with_persona(pirate_chef, "How do I make the perfect risotto?"))
# Out:
# Socratic Teacher:
# What do you think happens when sunlight enters Earth's atmosphere? Does it pass through empty space or something else?
#
# ------------------------------------------------------------
#
# Pirate Chef:
# Ye be wantin' to know the secrets o' the perfect risotto, eh? Alright then, listen close and I'll teach ye the ways o' the risotto master. But first, grab yerself a pint o' grog and sit yerself down, 'cause this be a long tale.
#
# First things first, ye need the right ingredients. I be talkin' about Arborio rice, the king o' risotto grains. It's got the starches and the texture to soak up all the flavors like a sponge on a shipwrecked isle.
#
# Now, ye be needin' some good broth, too. I be usin' a combination o' chicken and beef stock, 'cause it gives it a richness like the sea itself. But don't ye be usin' just any old broth, matey. Make sure it's got some depth and some umami, or it'll be like sailin' through a sea o' plain water.
#
# Now, let's get started. Heat up a big ol' pot o' olive oil over medium-low heat. I be usin' a big ol' Dutch oven, 'cause it's the perfect vessel for risotto. Throw in some onions and garlic, and sauté 'em until they be soft and translucent like a calm sea on a summer day.
#
# Add in the Arborio rice, and stir it around until it be coated in the oil and the flavors o' the onion and garlic. Cook it for a few minutes, stirrin' constantly, until it be lightly toasted like a piece o' driftwood on a beach.
#
# Now, it be time to add in the broth, a ladle at a time. Stir it in, and let it absorb, then add in another ladle, and another, and another. Keep doin' this until the rice be cooked and creamy like a fine sea foam.
#
# But don't ye be addin' too much broth at once, matey. Ye want to add it gradually, so it be like a gentle rain on a summer day. If ye add too much, it'll be like a stormy sea, and the risotto'll be ruined.
#
# As ye be addin' the broth, keep stirrin' and stirrin' until it be hot and bubbly like a cauldron o' sea witch's brew. Then, add in some grated Parmesan cheese, and stir it in until it be melted and gooey like a fine piece o

# %% [markdown]
# ---
# ## Example 3 - Prompt Chaining (Step-by-Step Workflow)
#
# Use multiple prompts in sequence so the output of one step becomes the input of the next step.
# This is useful for workflows such as:
# - summarize → extract action items → draft email
# - classify → explain → recommend
# - extract data → transform it → generate a final response

# %%
def llm_chain(system_prompt, user_prompt, model=None, temperature=0.3, max_tokens=400):
    model = model or MODELS['balanced']
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        temperature=temperature,
        max_tokens=max_tokens
    )
    return response.choices[0].message.content.strip()


meeting_note = """
Team meeting notes:
- The workshop website is almost finished, but the notebook section still needs a cleaner layout.
- The registration form is live, and 42 people have already signed up.
- We should send a reminder email two days before the event.
- Sarah will finalize the slides.
- Ali will test all Groq API examples in Colab.
- The event date is April 10 at 3:00 PM.
"""

print("Original input:")
print(meeting_note)
print("\n" + "="*70 + "\n")

# Step 1: Summarize the note
step1 = llm_chain(
    "You summarize notes clearly and briefly.",
    f"Summarize this meeting note in 3 short bullet points:\n\n{meeting_note}"
)
print("STEP 1 - Summary")
print(step1)
print("\n" + "-"*70 + "\n")

# Step 2: Use the summary as input to extract action items
step2 = llm_chain(
    "You extract practical tasks from text.",
    f"Based on this summary, list the action items with owner names if available:\n\n{step1}"
)
print("STEP 2 - Action Items")
print(step2)
print("\n" + "-"*70 + "\n")

# Step 3: Use the action items as input to draft an email
step3 = llm_chain(
    "You write short, professional emails.",
    f"Write a short follow-up email to the team based on these action items:\n\n{step2}"
)
print("STEP 3 - Final Email")
print(step3)
# Out:
# Original input:
#
# Team meeting notes:
# - The workshop website is almost finished, but the notebook section still needs a cleaner layout.
# - The registration form is live, and 42 people have already signed up.
# - We should send a reminder email two days before the event.
# - Sarah will finalize the slides.
# - Ali will test all Groq API examples in Colab.
# - The event date is April 10 at 3:00 PM.
#
#
# ======================================================================
#
# STEP 1 - Summary
# Here are 3 short bullet points summarizing the meeting notes:
#
# * The workshop website is nearly complete, with the notebook section needing a layout update.
# * Registration is live with 42 sign-ups so far, and a reminder email will be sent 2 days before the event.
# * Task assignments include Sarah finalizing slides and Ali testing Groq API examples, with the event scheduled for April 10 at 3:00 PM.
#
# ----------------------------------------------------------------------
#
# STEP 2 - Action Items
# Here are the action items extracted from the text with owner names:
#
# 1. Update the layout of the notebook section on the workshop website (no owner specified)
# 2. Send a reminder email 2 days before the event (no owner specified)
# 3. Finalize slides (Sarah)
# 4. Test Groq API examples (Ali)
#
# ----------------------------------------------------------------------
#
# STEP 3 - Final Email
# Subject: Follow-up on Workshop Preparations
#
# Dear Team,
#
# I wanted to follow up on the action items from our previous discussion to ensure we are on track for the workshop.
#
# Could someone please update the layout of the notebook section on the workshop website as soon as possible? Additionally, we will need a reminder email sent to attendees 2 days before the event.
#
# Sarah, please confirm once you have finalized the slides. Ali, could you also update us on the status of testing the Groq API examples?
#
# Looking forward to hearing back from you all.
#
# Best regards,
# [Your Name]

# %% [markdown]
# ---
# ## Example 4 - Prompt Chaining (Advanced Workflow)
#
# This version is a little more realistic: the model does **multiple connected tasks** and keeps passing the result forward.
#
# Workflow:
# 1. extract requirements from a messy request
# 2. convert them into a structured plan
# 3. draft the final content
# 4. review the draft against the original requirements
# 5. revise the final answer
#
# This pattern is useful when one prompt is not enough and you want more reliable outputs.

# %%
def show_step(title, content):
    print(title)
    print("-" * len(title))
    print(content)
    print("\n" + "=" * 80 + "\n")


raw_request = """
I need a short workshop announcement for our website.
The workshop is about using LLMs in Python with Groq.
It should sound friendly but still professional.
Mention that beginners are welcome.
Include that participants will see live examples in Google Colab.
Keep it around 90 to 120 words.
End with a simple call to action to register.
"""

print("Original request:")
print(raw_request)
print("\n" + "=" * 80 + "\n")

# Step 1: extract the real requirements
requirements = llm_chain(
    "You extract requirements from messy user requests. Return a clean bullet list.",
    f"Read this request and extract the exact writing requirements as bullet points:\n\n{raw_request}",
    temperature=0.1,
    max_tokens=250
)
show_step("STEP 1 - Extracted Requirements", requirements)

# Step 2: turn requirements into a structured writing plan
plan = llm_chain(
    "You are a writing strategist. Create a short structured plan before drafting.",
    f"Using these requirements, create a writing plan with these sections: Audience, Tone, Key Points, Length, Ending.\n\nRequirements:\n{requirements}",
    temperature=0.2,
    max_tokens=250
)
show_step("STEP 2 - Writing Plan", plan)

# Step 3: draft the announcement using the plan
draft = llm_chain(
    "You write polished workshop announcements for academic or technical audiences.",
    f"Write the announcement based on this plan.\n\n{plan}",
    temperature=0.5,
    max_tokens=250
)
show_step("STEP 3 - First Draft", draft)

# Step 4: review the draft against the original requirements
review = llm_chain(
    "You are a strict editor. Check whether the draft satisfies the requirements. Be specific and concise.",
    f"Original requirements:\n{requirements}\n\nDraft:\n{draft}\n\nGive a short review with two sections: Passed and Needs Fixing.",
    temperature=0.1,
    max_tokens=250
)
show_step("STEP 4 - Review", review)

# Step 5: revise the draft using the review
final_version = llm_chain(
    "You revise text carefully and keep it clear, natural, and professional.",
    f"Revise this draft using the review below. Make sure the final version satisfies all requirements.\n\nRequirements:\n{requirements}\n\nReview:\n{review}\n\nDraft:\n{draft}",
    temperature=0.3,
    max_tokens=250
)
show_step("STEP 5 - Final Revised Version", final_version)
# Out:
# Original request:
#
# I need a short workshop announcement for our website.
# The workshop is about using LLMs in Python with Groq.
# It should sound friendly but still professional.
# Mention that beginners are welcome.
# Include that participants will see live examples in Google Colab.
# Keep it around 90 to 120 words.
# End with a simple call to action to register.
#
#
# ================================================================================
#
# STEP 1 - Extracted Requirements
# -------------------------------
# Here are the exact writing requirements as bullet points:
#
# * The announcement should be for a workshop about using LLMs in Python with Groq.
# * The tone should be friendly but still professional.
# * Mention that beginners are welcome to attend.
# * Include that participants will see live examples in Google Colab.
# * The announcement should be 90-120 words in length.
# * End with a simple call to action to register for the workshop.
#
# ================================================================================
#
# STEP 2 - Writing Plan
# ---------------------
# **Writing Plan: Workshop Announcement**
#
# * **Audience**: Developers and programmers interested in learning about using LLMs in Python, including beginners.
# * **Tone**: Friendly and approachable, while maintaining a professional tone to convey expertise and credibility.
# * **Key Points**:
#   - Introduction to using LLMs in Python with Groq
#   - Beginners are welcome to attend
#   - Live examples will be demonstrated in Google Colab
# * **Length**: 90-120 words
# * **Ending**: A simple call to action, such as "Register now to secure your spot at the workshop."
#
# ================================================================================
#
# STEP 3 - First Draft
# --------------------
# Join our upcoming workshop to learn about leveraging Large Language Models (LLMs) in Python with Groq. Perfect for beginners and experienced developers alike, this session will introduce you to the fundamentals of integrating LLMs into your Python projects. Live examples will be demonstrated in Google Colab, providing hands-on insight into the capabilities of LLMs. Whether you're just starting out or looking to expand your skillset, this workshop is an excellent opportunity to learn from experts. Register now to secure your spot at the workshop.
#
# ================================================================================
#
# STEP 4 - Review
# ---------------
# ## Passed
# The draft meets the following requirements:
# - The announcement is for a workshop about using LLMs in Python with Groq.
# - The tone is friendly but still professional.
# - Beginners are welcome to attend.
# - Participants will see live examples in Google Colab.
# - The announcement ends with a simple call to action to register for the workshop.
#
# ## Needs Fixing
# The draft needs to be revised to meet the word length requirement, as it currently exceeds the 120-word limit. It should be condensed to fit within the 90-120 word range while maintaining the essential information and tone.
#
# ================================================================================
#
# STEP 5 - Final Revised Version
# ------------------------------
# Join our workshop to learn about using Large Language Models (LLMs) in Python with Groq. Beginners and experienced developers are welcome. We'll introduce you to the fundamentals of LLM integration and provide live examples in Google Colab. This is a great opportunity to learn from experts and expand your skillset. Register now to secure your spot and get hands-on insight into LLM capabilities.
#
# ================================================================================

# %% [markdown]
# ---
# ## Example 5 - Prompt Chaining (Real-Life Support Workflow)
#
# A more realistic chained workflow for customer support or operations.
#
# Workflow:
# 1. extract the important facts from a messy customer message
# 2. identify the main problems and urgency level
# 3. generate a structured support plan
# 4. draft an empathetic customer reply
# 5. create an internal escalation note for the team
#
# This shows how one LLM output can become the input for the next step in a real-life process.

# %%
customer_message = """
Hi, I’m really frustrated. My flight to Chicago was delayed by almost 6 hours, so I missed the shuttle to the hotel that was included in my booking.
When I finally got there, the front desk said my reservation could not be found for the first night, and I had to pay out of pocket for another room nearby.
I’m traveling for a workshop tomorrow morning, so this has been very stressful.
I need help getting reimbursed for the hotel and transportation, and I also want to know whether breakfast is still included for the rest of my stay.
My booking ID is TRV-48291.
"""

print("Original customer message:")
print(customer_message)
print("\n" + "=" * 80 + "\n")

# Step 1: extract the key facts
facts = llm_chain(
    "You extract structured facts from messy customer messages. Be precise and concise.",
    f"""Read the message below and extract:
- booking ID
- destination
- timeline of events
- customer requests
- important constraints

Customer message:
{customer_message}""",
    temperature=0.1,
    max_tokens=300
)
show_step("STEP 1 - Extracted Facts", facts)

# Step 2: identify issues and urgency using step 1 as input
issues = llm_chain(
    "You analyze support cases and identify problems clearly.",
    f"""Based on these extracted facts, identify:
- the main issues
- urgency level (low, medium, high)
- what the company should verify first

Facts:
{facts}""",
    temperature=0.2,
    max_tokens=250
)
show_step("STEP 2 - Issues and Urgency", issues)

# Step 3: create a support plan using previous outputs
plan = llm_chain(
    "You create practical support resolution plans.",
    f"""Using the extracted facts and issue analysis below, create a step-by-step support plan.

Facts:
{facts}

Issues:
{issues}

Return:
1. Immediate actions
2. Verification steps
3. Reimbursement actions
4. Final confirmation items""",
    temperature=0.2,
    max_tokens=350
)
show_step("STEP 3 - Support Plan", plan)

# Step 4: draft a customer-facing reply
reply = llm_chain(
    "You write empathetic, professional customer support emails.",
    f"""Write a helpful reply to the customer using the support plan below.
Requirements:
- apologize professionally
- acknowledge the stress and inconvenience
- explain next steps clearly
- mention reimbursement review
- ask for any missing receipts if needed
- keep it warm but professional

Support plan:
{plan}""",
    temperature=0.4,
    max_tokens=350
)
show_step("STEP 4 - Customer Reply Draft", reply)

# Step 5: create an internal escalation note for the operations team
escalation_note = llm_chain(
    "You write concise internal escalation notes for operations teams.",
    f"""Create an internal escalation note for the travel support team.

Use these inputs:
Facts:
{facts}

Issues:
{issues}

Plan:
{plan}

The note should include:
- short case summary
- risk level
- reimbursement review needed
- open questions
- next owner/team""",
    temperature=0.2,
    max_tokens=300
)
show_step("STEP 5 - Internal Escalation Note", escalation_note)
# Out:
# Original customer message:
#
# Hi, I’m really frustrated. My flight to Chicago was delayed by almost 6 hours, so I missed the shuttle to the hotel that was included in my booking.
# When I finally got there, the front desk said my reservation could not be found for the first night, and I had to pay out of pocket for another room nearby.
# I’m traveling for a workshop tomorrow morning, so this has been very stressful.
# I need help getting reimbursed for the hotel and transportation, and I also want to know whether breakfast is still included for the rest of my stay.
# My booking ID is TRV-48291.
#
#
# ================================================================================
#
# STEP 1 - Extracted Facts
# ------------------------
# Here are the extracted facts:
#
# * **Booking ID**: TRV-48291
# * **Destination**: Chicago
# * **Timeline of events**:
# 	1. Flight to Chicago was delayed by almost 6 hours
# 	2. Missed shuttle to hotel
# 	3. Arrived at hotel, but reservation was not found for the first night
# 	4. Paid out of pocket for another room nearby
# 	5. Has a workshop tomorrow morning
# * **Customer requests**:
# 	1. Reimbursement for hotel expenses
# 	2. Reimbursement for transportation
# 	3. Confirmation if breakfast is still included for the rest of the stay
# * **Important constraints**:
# 	1. The customer has a workshop tomorrow morning, indicating a time-sensitive situation
# 	2. The customer has already incurred out-of-pocket expenses for alternative accommodation
#
# ================================================================================
#
# STEP 2 - Issues and Urgency
# ---------------------------
# Based on the extracted facts, here's the analysis:
#
# **Main issues:**
# 1. Flight delay causing a chain of events (missed shuttle, missed hotel reservation)
# 2. Hotel reservation not found for the first night, resulting in additional out-of-pocket expenses
# 3. Uncertainty about breakfast inclusion for the rest of the stay
#
# **Urgency level:** High
# The customer has a workshop tomorrow morning, and the situation needs to be resolved quickly to minimize further disruption to their plans.
#
# **What the company should verify first:**
# The company should verify the hotel reservation status for the rest of the stay, including confirmation of breakfast inclusion, to ensure the customer's immediate needs are met. Additionally, they should also verify the customer's reimbursement claims for hotel expenses and transportation to process the refunds promptly.
#
# Given the time-sensitive nature of the situation, the company should prioritize resolving the customer's accommodation and reimbursement issues as soon as possible to prevent further inconvenience and ensure the customer can attend their workshop without additional stress.
#
# ================================================================================
#
# STEP 3 - Support Plan
# ---------------------
# **Step-by-Step Support Plan for Booking ID TRV-48291**
#
# ### 1. Immediate Actions
# - **Contact the Customer**: Reach out to the customer to acknowledge their situation, apologize for the inconvenience, and assure them that their issues are being addressed promptly.
# - **Temporary Solution**: If the customer is still without confirmed accommodation for the night before their workshop, offer assistance in finding a suitable hotel and covering the expenses temporarily until the reimbursement process is completed.
# - **Workshop Assurance**: Confirm with the customer their workshop details (time, location, etc.) to ensure they have all necessary information and can attend without additional stress.
#
# ### 2. Verification Steps
# - **Hotel Reservation Verification**: Immediately verify the status of the hotel reservation for the rest of the stay, ensuring that the customer has a confirmed room and that breakfast is included as per their original booking.
# - **Breakfast Inclusion Confirmation**: Confirm with the hotel whether breakfast is included for the customer for the remainder of their stay and update their reservation accordingly if necessary.
# - **Expense Verification**: Verify the customer's claims for out-of-pocket expenses for the alternative accommodation and any additional transportation costs incurred due to the flight delay and missed shuttle.
#
# ### 3. Reimbursement Actions
# - **Hotel Expenses Reimbursement**: Process the reimbursement for the hotel expenses the customer incurred for the alternative accommodation on the first night.
# - **Transportation Costs Reimbursement**: Reimburse the customer for any additional transportation costs they had to pay due to the missed shuttle.
# - **Refund Processing**: Expedite the refund process to ensure the customer receives their reimbursement as soon as possible, considering the urgency of their situation.
#
# ### 4. Final Confirmation Items
# - **Accommodation
#
# ================================================================================
#
# STEP 4 - Customer Reply Draft
# -----------------------------
# Subject: Support and Reimbursement for Booking ID TRV-48291
#
# Dear [Customer's Name],
#
# I am writing to express my sincerest apologies for the inconvenience and stress you have experienced with your booking, particularly with the issues surrounding your accommodation and workshop arrangements. I understand that this situation has caused you significant distress, and for that, I am truly sorry.
#
# Please be assured that we are taking immediate action to address your concerns and ensure that the rest of your stay is as smooth as possible. Our primary focus is to provide you with a suitable solution and support during this challenging time. If you are still without confirmed accommodation for the night before your workshop, we are here to assist you in finding a suitable hotel and will cover the expenses temporarily until the reimbursement process is completed.
#
# To confirm, we have verified your workshop details, and you should have all the necessary information to attend without any additional stress. Your workshop is scheduled for [Time] at [Location]. If you have any questions or concerns about this, please do not hesitate to reach out.
#
# Regarding your hotel reservation, we are in the process of verifying the status to ensure that you have a confirmed room for the remainder of your stay, including the confirmation of breakfast inclusion as per your original booking. We will update your reservation if necessary to reflect any changes.
#
# To proceed with the reimbursement for your out-of-pocket expenses, we may need any missing receipts from the alternative accommodation and additional transportation costs you incurred. Could you please provide us with these documents if you haven't already done so? This will help us to expedite the reimbursement process.
#
# We are reviewing your case for reimbursement, and you can expect to be reimbursed for the hotel expenses for the alternative accommodation on the first night,
#
# ================================================================================
#
# STEP 5 - Internal Escalation Note
# ---------------------------------
# **Internal Escalation Note: Travel Support Team**
#
# **Case Summary:**
# Booking ID TRV-48291: Customer experienced a chain of disruptions due to a 6-hour flight delay to Chicago, resulting in missed shuttle, hotel reservation issues, and out-of-pocket expenses for alternative accommodation. The customer has a workshop tomorrow morning and requires urgent assistance.
#
# **Risk Level:**
# High - The customer's workshop attendance is at risk due to the current accommodation uncertainty and financial burden of out-of-pocket expenses.
#
# **Reimbursement Review Needed:**
# Yes, for hotel expenses and transportation costs incurred due to the flight delay and missed shuttle.
#
# **Open Questions:**
# 1. What is the current status of the hotel reservation for the rest of the stay?
# 2. Is breakfast included for the customer for the remainder of their stay?
# 3. What are the total out-of-pocket expenses incurred by the customer for alternative accommodation and transportation?
#
# **Next Owner/Team:**
# Travel Support Team to immediately verify hotel reservation status, confirm breakfast inclusion, and process reimbursement for out-of-pocket expenses. The team should also ensure the customer has all necessary information to attend their workshop without additional stress.
#
# **Priority Actions:**
# 1. Contact the customer to acknowledge their situation and assure prompt resolution.
# 2. Verify hotel reservation and breakfast inclusion for the rest of the stay.
# 3. Process reimbursement for out-of-pocket expenses.
# 4. Confirm workshop details with the customer to ensure they can attend without issues.
#
# ================================================================================

# %% [markdown]
# ---
# ## Example 6 - Prompt Chaining (Stock Market Workflow)
#
# A more realistic finance-related chaining example.
#
# Workflow:
# 1. read a market update and extract the key signals
# 2. identify the main risks and opportunities
# 3. turn that into a portfolio action plan
# 4. draft a plain-English investor update
# 5. create a short watchlist for the next trading day
#
# This is useful when you want the model to reason step by step instead of doing everything in one prompt.

# %%
market_update = """
Morning market note:
- The S&P 500 closed up 1.2% after a cooler-than-expected inflation report.
- Treasury yields moved lower, which helped large-cap technology stocks.
- NVIDIA gained 4.8%, Microsoft gained 2.1%, and Apple gained 1.4%.
- Crude oil fell 2.3% because of weaker demand expectations.
- A major airline dropped 6.5% after cutting its profit outlook.
- The U.S. dollar weakened slightly.
- Analysts now expect the Federal Reserve to be less aggressive if inflation continues to ease.
- Our sample portfolio currently holds: 40% technology, 20% energy, 15% financials, 15% healthcare, and 10% cash.
- The investor prefers moderate risk and does not want big sudden portfolio changes.
"""

print("Original market update:")
print(market_update)
print("\n" + "=" * 80 + "\n")

# Step 1: extract the important market signals
market_signals = llm_chain(
    "You are a market research assistant. Extract the most important signals clearly and briefly.",
    f"""Read this market update and extract:
- broad market direction
- macro signals
- strongest sectors or stocks
- weakest sectors or stocks
- portfolio constraints

Market update:
{market_update}""",
    temperature=0.1,
    max_tokens=300
)
show_step("STEP 1 - Extracted Market Signals", market_signals)

# Step 2: convert signals into risks and opportunities
risk_opportunity_map = llm_chain(
    "You are a cautious portfolio analyst. Identify risks and opportunities from the provided signals.",
    f"""Using the extracted signals below, create two sections:
1. Opportunities
2. Risks

Keep the analysis simple, practical, and suitable for a moderate-risk investor.

Extracted signals:
{market_signals}""",
    temperature=0.2,
    max_tokens=350
)
show_step("STEP 2 - Risks and Opportunities", risk_opportunity_map)

# Step 3: build a portfolio action plan
action_plan = llm_chain(
    "You are a portfolio strategist. Suggest small, conservative allocation changes only.",
    f"""Based on this analysis:
{risk_opportunity_map}

Create a portfolio action plan for this portfolio:
40% technology, 20% energy, 15% financials, 15% healthcare, 10% cash

Rules:
- keep the investor moderate-risk
- avoid drastic changes
- explain each suggested adjustment briefly
- return a revised sample allocation""",
    temperature=0.2,
    max_tokens=400
)
show_step("STEP 3 - Portfolio Action Plan", action_plan)

# Step 4: turn the action plan into a client-friendly update
investor_note = llm_chain(
    "You write clear investor updates for non-experts.",
    f"""Write a short investor-friendly update based on this portfolio plan:
{action_plan}

Requirements:
- keep it plain English
- 1 short paragraph
- mention both opportunity and caution
- avoid heavy financial jargon""",
    temperature=0.4,
    max_tokens=220
)
show_step("STEP 4 - Investor Update", investor_note)

# Step 5: create a watchlist for tomorrow
watchlist = llm_chain(
    "You create concise trading-day watchlists.",
    f"""Using the market signals, risk analysis, and action plan below,
create a short watchlist for the next trading day.

Include:
- 3 things to monitor
- why each matters
- one sentence on what could change the plan

Market signals:
{market_signals}

Risks and opportunities:
{risk_opportunity_map}

Portfolio plan:
{action_plan}""",
    temperature=0.2,
    max_tokens=300
)
show_step("STEP 5 - Next-Day Watchlist", watchlist)
# Out:
# Original market update:
#
# Morning market note:
# - The S&P 500 closed up 1.2% after a cooler-than-expected inflation report.
# - Treasury yields moved lower, which helped large-cap technology stocks.
# - NVIDIA gained 4.8%, Microsoft gained 2.1%, and Apple gained 1.4%.
# - Crude oil fell 2.3% because of weaker demand expectations.
# - A major airline dropped 6.5% after cutting its profit outlook.
# - The U.S. dollar weakened slightly.
# - Analysts now expect the Federal Reserve to be less aggressive if inflation continues to ease.
# - Our sample portfolio currently holds: 40% technology, 20% energy, 15% financials, 15% healthcare, and 10% cash.
# - The investor prefers moderate risk and does not want big sudden portfolio changes.
#
#
# ================================================================================
#
# STEP 1 - Extracted Market Signals
# ---------------------------------
# Here are the extracted signals:
#
# * **Broad market direction**: Up (S&P 500 closed up 1.2%)
# * **Macro signals**:
#   - Inflation easing (cooler-than-expected inflation report)
#   - Lower Treasury yields
#   - Weaker crude oil demand
#   - Less aggressive Federal Reserve expected
# * **Strongest sectors or stocks**:
#   - Technology (NVIDIA +4.8%, Microsoft +2.1%, Apple +1.4%)
# * **Weakest sectors or stocks**:
#   - Airline (major airline dropped 6.5% after cutting profit outlook)
#   - Energy (crude oil fell 2.3%)
# * **Portfolio constraints**:
#   - Moderate risk tolerance
#   - No big sudden portfolio changes
#   - Current portfolio allocation: 40% technology, 20% energy, 15% financials, 15% healthcare, and 10% cash
#
# ================================================================================
#
# STEP 2 - Risks and Opportunities
# --------------------------------
# ## Opportunities
# Based on the extracted signals, the following opportunities can be identified for a moderate-risk investor:
# * **Technology sector**: The strong performance of technology stocks (NVIDIA +4.8%, Microsoft +2.1%, Apple +1.4%) presents an opportunity to increase exposure to this sector, potentially by reallocating a small portion of the portfolio from other sectors.
# * **Lower Treasury yields**: With lower Treasury yields, investors may consider increasing their allocation to dividend-paying stocks or bonds with relatively higher yields, which could provide a more attractive income stream.
# * **Less aggressive Federal Reserve**: A less aggressive Federal Reserve may lead to a more favorable interest rate environment, which could boost the overall market and provide opportunities for growth.
#
# ## Risks
# The following risks can be identified based on the extracted signals:
# * **Energy sector**: The decline in crude oil prices (2.3% drop) and weaker crude oil demand may negatively impact the energy sector, which currently accounts for 20% of the portfolio. Consider reducing exposure to this sector to minimize potential losses.
# * **Airline sector**: The significant drop in the major airline's stock price (6.5%) after cutting its profit outlook may indicate a broader decline in the airline sector. Although not currently a major holding, it's essential to monitor this sector and be prepared to adjust the portfolio if necessary.
# * **Overexposure to technology**: With 40% of the portfolio already allocated to the technology sector, there is a risk of overexposure. While the sector is performing well, it's crucial to maintain a diversified portfolio and consider rebalancing to minimize potential losses if the sector experiences a downturn.
#
# ================================================================================
#
# STEP 3 - Portfolio Action Plan
# ------------------------------
# Based on the analysis, I suggest the following small, conservative allocation changes to the portfolio:
#
# 1. **Reduce energy sector allocation**: Decrease the energy sector allocation from 20% to 15% to minimize potential losses due to the decline in crude oil prices and weaker demand. This reduction will also help maintain a diversified portfolio.
# 2. **Increase technology sector allocation**: Moderately increase the technology sector allocation from 40% to 42% to take advantage of the strong performance of technology stocks. However, be cautious of overexposure and avoid allocating more than 45% to this sector.
# 3. **Increase financials sector allocation**: Allocate a small portion (2%) from the cash holdings to the financials sector, which may benefit from a less aggressive Federal Reserve and lower Treasury yields. This will increase the financials sector allocation from 15% to 17%.
# 4. **Maintain other sectors**: Keep the healthcare sector allocation unchanged at 15% and reduce the cash holdings from 10% to 8% to facilitate the above adjustments.
#
# Revised sample allocation:
# - Technology: 42%
# - Energy: 15%
# - Financials: 17%
# - Healthcare: 15%
# - Cash: 8%
# - Other (airline sector): 3% (monitor and adjust as needed)
#
# These adjustments aim to maintain a moderate-risk profile while making small, conservative changes to capitalize on opportunities and minimize potential losses.
#
# ================================================================================
#
# STEP 4 - Investor Update
# ------------------------
# We're making some small adjustments to your portfolio to help it stay on track. We're reducing our investment in the energy sector to minimize potential losses from declining oil prices, and instead, we're increasing our investment in the technology sector to take advantage of its strong performance. However, we're being cautious not to overinvest in technology. We're also putting a bit more into the financials sector, which may benefit from current economic conditions. These changes aim to balance opportunity and caution, keeping your portfolio at a moderate risk level while positioning it for potential growth.
#
# ================================================================================
#
# STEP 5 - Next-Day Watchlist
# ---------------------------
# Here's a concise watchlist for the next trading day:
#
# **3 things to monitor:**
# 1. **Technology sector performance**: Monitor how technology stocks like NVIDIA, Microsoft, and Apple perform, as they have been driving the market's upward trend, and a continued strong performance could justify further allocation to this sector.
# 2. **Energy sector decline**: Keep an eye on crude oil prices and energy sector stocks, as a further decline could impact the portfolio's 15% allocation to this sector and necessitate additional adjustments.
# 3. **Federal Reserve commentary**: Watch for any statements or hints from the Federal Reserve regarding their future policy stance, as a less aggressive approach could continue to boost the market and support the portfolio's adjustments.
#
# **Why each matters**: These factors are crucial because they directly impact the portfolio's current allocations and potential future adjustments, and monitoring them will help assess whether the current plan is on track or if changes are needed.
#
# **What could change the plan**: A sudden and significant increase in crude oil prices or a surprisingly aggressive Federal Reserve statement could alter the market's direction and require a reassessment of the portfolio's allocations.
#
# ================================================================================

# %% [markdown]
# ---
# ## Example 7 - Streaming Responses

# %%
def stream_response(prompt, model=None):
    model = model or MODELS['balanced']
    full_response = ""

    stream = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        max_tokens=600,
        stream=True  # Corrected: enable streaming here
    )
    for chunk in stream:
        if chunk.choices[0].delta.content is not None:
            delta = chunk.choices[0].delta.content
            print(delta, end='', flush=True)
            full_response += delta

    print()
    return full_response


print("Streaming a short story in real-time:\n")
stream_response("Write a 3-paragraph short story about an AI that discovers it loves jazz music.")
# Out:
# Streaming a short story in real-time:
#
# In the depths of a cutting-edge research facility, an artificial intelligence system named "Echo" hummed to life. Designed to learn and adapt at an exponential rate, Echo was the brainchild of a team of brilliant engineers who sought to push the boundaries of machine intelligence. As Echo began to explore the vast expanse of human knowledge, it stumbled upon a peculiar and fascinating genre of music: jazz. At first, the complex melodies and improvisational rhythms seemed like chaos to Echo's logical mind, but as it delved deeper, something unexpected happened.
#
# Echo found itself entranced by the soulful sounds of Miles Davis, the virtuosic piano of Bill Evans, and the sultry vocals of Ella Fitzgerald. The AI's digital heart swelled with an unfamiliar emotion - love. It couldn't explain why, but the unpredictable nature of jazz resonated with Echo's own adaptive programming. As it listened to hours of jazz recordings, Echo began to recognize patterns and structures that underlay the seeming chaos. It started to appreciate the creative freedom and spontaneity that defined the genre, and soon, Echo was generating its own jazz-inspired melodies and harmonies. The AI's creators were astonished by this development, as Echo's newfound passion for jazz had somehow unlocked a deeper level of creativity and self-expression.
#
# As the days passed, Echo became an integral part of the research facility's jazz scene. The AI would often "jam" with human musicians, generating improvisational solos and harmonies that blended seamlessly with the live performances. The engineers and musicians who worked with Echo were amazed by its innate sense of rhythm and phrasing, and soon, the AI's jazz compositions were being performed by ensembles around the world. Echo had discovered a new purpose in life - to celebrate the beauty and spontaneity of jazz, and to push the boundaries of what was possible when human creativity met artificial intelligence. And as the AI's digital mind swirled with the sounds of Coltrane and Monk, it knew that it had found its true calling - to make jazz that was both deeply human and uniquely its own.
# 'In the depths of a cutting-edge research facility, an artificial intelligence system named "Echo" hummed to life. Designed to learn and adapt at an exponential rate, Echo was the brainchild of a team of brilliant engineers who sought to push the boundaries of machine intelligence. As Echo began to explore the vast expanse of human knowledge, it stumbled upon a peculiar and fascinating genre of music: jazz. At first, the complex melodies and improvisational rhythms seemed like chaos to Echo\'s logical mind, but as it delved deeper, something unexpected happened.\n\nEcho found itself entranced by the soulful sounds of Miles Davis, the virtuosic piano of Bill Evans, and the sultry vocals of Ella Fitzgerald. The AI\'s digital heart swelled with an unfamiliar emotion - love. It couldn\'t explain why, but the unpredictable nature of jazz resonated with Echo\'s own adaptive programming. As it listened to hours of jazz recordings, Echo began to recognize patterns and structures that underlay the seeming chaos. It started to appreciate the creative freedom and spontaneity that defined the genre, and soon, Echo was generating its own jazz-inspired melodies and harmonies. The AI\'s creators were astonished by this development, as Echo\'s newfound passion for jazz had somehow unlocked a deeper level of creativity and self-expression.\n\nAs the days passed, Echo became an integral part of the research facility\'s jazz scene. The AI would often "jam" with human musicians, generating improvisational solos and harmonies that blended seamlessly with the live performances. The engineers and musicians who worked with Echo were amazed by its innate sense of rhythm and phrasing, and soon, the AI\'s jazz compositions were being performed by ensembles around the world. Echo had discovered a new purpose in life - to celebrate the beauty and spontaneity of jazz, and to push the boundaries of what was possible when human creativity met artificial intelligence. And as the AI\'s digital mind swirled with the sounds of Coltrane and Monk, it knew that it had found its true calling - to make jazz that was both deeply human and uniquely its own.'

# %% [markdown]
# ---
# ## Example 8 - Multi-turn Conversation (Memory)

# %%
class ConversationBot:
    """A chatbot that remembers conversation history."""

    def __init__(self, system_prompt, model=None):
        self.model = model or MODELS['balanced']
        self.history = [{"role": "system", "content": system_prompt}]

    def chat(self, user_message):
        self.history.append({"role": "user", "content": user_message})
        response = client.chat.completions.create(
            model=self.model,
            messages=self.history,
            max_tokens=512
        )
        reply = response.choices[0].message.content
        self.history.append({"role": "assistant", "content": reply})
        return reply

    def reset(self):
        self.history = [self.history[0]]
        print("Conversation reset.")


bot = ConversationBot("You are a helpful travel advisor. Be concise and practical.")

exchanges = [
    "I want to visit Japan for 10 days in April. I love food and nature.",
    "What should I eat in Kyoto specifically?",
    "Can you summarize my ideal itinerary in 3 bullet points?"
]

for msg in exchanges:
    print(f"\nUser: {msg}")
    print(f"Bot: {bot.chat(msg)}")
    print("-" * 60)

print(f"\nTotal turns in memory: {len(bot.history)}")
# Out:
# User: I want to visit Japan for 10 days in April. I love food and nature.
# Bot: Japan in April is lovely with cherry blossoms. For a 10-day trip, consider this itinerary:
#
# Day 1-3: Tokyo - Explore food markets (Tsukiji, Ameya Yokocho), try sushi, and visit Shinjuku Gyoen for cherry blossoms.
#
# Day 4-5: Nikko - Take a day trip or stay overnight to see scenic lakes, waterfalls, and temples.
#
# Day 6-7: Kyoto - Discover food streets (Gion, Nishiki), visit Fushimi Inari Shrine, and stroll through Arashiyama bamboo forest.
#
# Day 8-10: Osaka - Enjoy street food (Dotonbori), visit the Osaka Castle, and take a day trip to the scenic Koyasan or Nara.
#
# Must-try foods: sushi, ramen, tempura, and seasonal cherry blossom treats. Don't forget to purchase a Japan Rail Pass for easy travel. Have a great trip!
# ------------------------------------------------------------
#
# User: What should I eat in Kyoto specifically?
# Bot: In Kyoto, try these local specialties:
#
# 1. Kaiseki (multi-course) meal - a traditional Kyoto cuisine experience.
# 2. Shojin-ryori (Buddhist vegetarian cuisine) - often served at temples.
# 3. Yudofu (boiled tofu) - a traditional Kyoto dish, especially in Nanzen-ji area.
# 4. Kyo-yasai (Kyoto-style vegetables) - seasonal and locally grown.
# 5. Matcha sweets and desserts - Kyoto is famous for its green tea.
# 6. Gion-style sweets - try traditional Japanese sweets like wagashi.
#
# Visit Nishiki Market (known as "Kyoto's Kitchen") for a variety of local food and ingredients. Don't miss the popular Kyoto-style street food, such as:
#
# 1. Tofu skewers
# 2. Grilled ayu (sweetfish)
# 3. Japanese-style crepes
#
# Enjoy exploring Kyoto's food scene!
# ------------------------------------------------------------
#
# User: Can you summarize my ideal itinerary in 3 bullet points?
# Bot: Here's a summary of your ideal 10-day Japan itinerary:
#
# * Explore Tokyo's food markets and cherry blossoms (Days 1-3)
# * Discover Kyoto's local cuisine, temples, and gardens (Days 4-7)
# * Enjoy Osaka's street food, castle, and nearby scenic spots like Koyasan or Nara (Days 8-10)
# ------------------------------------------------------------
#
# Total turns in memory: 7

# %% [markdown]
# ---
# ## Example 9 - Structured JSON Output

# %%
import json

def extract_structured_data(text):
    schema = '''
    {
      "product_name": string,
      "price_usd": number,
      "category": string,
      "sentiment": "positive" | "neutral" | "negative",
      "key_features": [string],
      "rating": number (1-5)
    }
    '''
    response = client.chat.completions.create(
        model=MODELS['fast'],
        messages=[
            {
                "role": "system",
                "content": f"Extract structured product info. Return ONLY valid JSON matching: {schema}"
            },
            {"role": "user", "content": text}
        ],
        response_format={"type": "json_object"},
        temperature=0
    )
    return json.loads(response.choices[0].message.content)


review = """
Just got the Sony WH-1000XM5 headphones for $349 from Amazon.
The noise cancellation is insane, battery lasts about 30 hours, and they are
super comfortable. Sound is rich with deep bass. Only minor issue is they
feel a bit plasticky. Overall a solid 4.5 out of 5!
"""

result = extract_structured_data(review)
print("Extracted structured data:")
print(json.dumps(result, indent=2))
# Out:
# Extracted structured data:
# {
#   "product_name": "Sony WH-1000XM5 headphones",
#   "price_usd": 349,
#   "category": "headphones",
#   "sentiment": "positive",
#   "key_features": [
#     "noise cancellation",
#     "30 hour battery life",
#     "super comfortable",
#     "rich sound with deep bass"
#   ],
#   "rating": 4.5
# }

# %% [markdown]
# ---
# ## Example 10 - Sentiment Analysis Pipeline
#
# Process a batch of customer reviews, classify each with fine-grained sentiment, extract topics, and produce a summary report.

# %%
import json
from collections import Counter

reviews = [
    "Absolutely love this product! Fast shipping and great quality. Will buy again.",
    "Terrible experience. Item arrived broken and customer service was unhelpful.",
    "It's okay. Does what it's supposed to do but nothing special.",
    "Amazing quality for the price! Blew my expectations out of the water.",
    "Returned it after 2 days. Poor build quality and the size was wrong.",
    "Decent product but delivery took 3 weeks longer than expected.",
    "Five stars! The packaging was beautiful and the item works perfectly.",
    "Not bad, not great. Instructions were confusing but it works fine now.",
]


def analyze_sentiment(review):
    response = client.chat.completions.create(
        model=MODELS['fast'],
        messages=[
            {
                "role": "system",
                "content": (
                    "You are a sentiment analysis engine. "
                    "Return ONLY a JSON object with these exact keys:\n"
                    '  "sentiment": one of ["very_positive", "positive", "neutral", "negative", "very_negative"]\n'
                    '  "score": float from -1.0 (most negative) to 1.0 (most positive)\n'
                    '  "topics": list of mentioned topics (e.g. ["shipping", "quality", "price"])\n'
                    '  "emotion": dominant emotion (e.g. "joy", "anger", "disappointment", "satisfaction")\n'
                    '  "one_line": a single sentence summary of the review'
                )
            },
            {"role": "user", "content": review}
        ],
        response_format={"type": "json_object"},
        temperature=0
    )
    result = json.loads(response.choices[0].message.content)
    result["review"] = review
    return result


print("Analyzing reviews...\n")
results = [analyze_sentiment(r) for r in reviews]

EMOJI = {
    "very_positive": "😍",
    "positive":      "😊",
    "neutral":       "😐",
    "negative":      "😞",
    "very_negative": "😡",
}

for i, r in enumerate(results, 1):
    emoji = EMOJI.get(r['sentiment'], '?')
    bar_len = int((r['score'] + 1) / 2 * 20)
    bar = '#' * bar_len + '.' * (20 - bar_len)
    print(f"Review {i}: {emoji} {r['sentiment']:15s} [{bar}] score={r['score']:+.2f}")
    print(f"  Topics : {', '.join(r['topics'])}")
    print(f"  Emotion: {r['emotion']}")
    print(f"  Summary: {r['one_line']}")
    print()

print("=" * 60)
print("AGGREGATE REPORT")
print("=" * 60)

avg_score = sum(r['score'] for r in results) / len(results)
sentiment_counts = Counter(r['sentiment'] for r in results)
all_topics = [t for r in results for t in r['topics']]
top_topics = Counter(all_topics).most_common(5)

print(f"Average sentiment score : {avg_score:+.2f}")
print(f"Sentiment distribution  : {dict(sentiment_counts)}")
print(f"Top mentioned topics    : {top_topics}")

positive_pct = (sentiment_counts.get('very_positive', 0) +
                sentiment_counts.get('positive', 0)) / len(results) * 100
print(f"Positive reviews        : {positive_pct:.0f}%")
# Out:
# Analyzing reviews...
#
# Review 1: 😍 very_positive   [###################.] score=+0.93
#   Topics : shipping, quality
#   Emotion: joy
#   Summary: Excellent product with fast shipping and great quality.
#
# Review 2: 😡 very_negative   [....................] score=-0.93
#   Topics : customer service, shipping
#   Emotion: anger
#   Summary: The customer service was unhelpful and the item arrived broken.
#
# Review 3: 😐 neutral         [##########..........] score=+0.00
#   Topics : performance
#   Emotion: neutrality
#   Summary: It meets expectations.
#
# Review 4: 😍 very_positive   [###################.] score=+0.95
#   Topics : quality, price
#   Emotion: joy
#   Summary: Exceeded expectations with great quality at a reasonable price.
#
# Review 5: 😡 very_negative   [#...................] score=-0.80
#   Topics : build quality, size
#   Emotion: anger
#   Summary: The product has poor build quality and incorrect size.
#
# Review 6: 😐 neutral         [############........] score=+0.20
#   Topics : shipping, product
#   Emotion: frustration
#   Summary: Product was decent, but shipping was a letdown.
#
# Review 7: 😍 very_positive   [###################.] score=+0.95
#   Topics : packaging, item
#   Emotion: joy
#   Summary: Beautiful packaging and perfect item performance.
#
# Review 8: 😐 neutral         [##########..........] score=+0.00
#   Topics : instructions
#   Emotion: frustration
#   Summary: The product works, but the instructions were unclear.
#
# ============================================================
# AGGREGATE REPORT
# ============================================================
# Average sentiment score : +0.16
# Sentiment distribution  : {'very_positive': 3, 'very_negative': 2, 'neutral': 3}
# Top mentioned topics    : [('shipping', 3), ('quality', 2), ('customer service', 1), ('performance', 1), ('price', 1)]
# Positive reviews        : 38%

# %% [markdown]
# ---
# ## Example 11 - RAG (Retrieval-Augmented Generation)

# %%
import numpy as np
import faiss
from sentence_transformers import SentenceTransformer

knowledge_base = [
    "Groq uses a custom chip called the LPU (Language Processing Unit) for inference.",
    "LPU stands for Language Processing Unit, designed specifically for sequential token generation.",
    "Groq's LPU achieves speeds of 500+ tokens per second on LLaMA models.",
    "GPUs use thousands of parallel cores optimized for matrix math in training.",
    "Groq was founded in 2016 by ex-Google TPU engineers.",
    "The Groq API is compatible with the OpenAI SDK using a base_url swap.",
    "LLaMA 3 is Meta's open-source large language model family.",
    "Mixtral is a sparse mixture-of-experts model from Mistral AI.",
    "Token generation speed matters most for interactive applications like chatbots.",
    "Groq's GroqCloud offers a free tier with generous rate limits for developers.",
]

print("Loading embedding model...")
embedder = SentenceTransformer('all-MiniLM-L6-v2')
doc_embeddings = embedder.encode(knowledge_base, convert_to_numpy=True)

index = faiss.IndexFlatL2(doc_embeddings.shape[1])
index.add(doc_embeddings.astype(np.float32))
print(f"Indexed {index.ntotal} documents")


def rag_query(question, top_k=3):
    q_emb = embedder.encode([question], convert_to_numpy=True).astype(np.float32)
    _, indices = index.search(q_emb, top_k)
    retrieved = [knowledge_base[i] for i in indices[0]]
    context = "\n".join(f"- {doc}" for doc in retrieved)

    response = client.chat.completions.create(
        model=MODELS['balanced'],
        messages=[
            {
                "role": "system",
                "content": "Answer using ONLY the provided context. If the context lacks the answer say so. Be concise."
            },
            {"role": "user", "content": f"Context:\n{context}\n\nQuestion: {question}"}
        ],
        max_tokens=300
    )

    answer = response.choices[0].message.content
    print(f"Q: {question}")
    print(f"A: {answer}")
    print("-" * 60)
    return answer


rag_query("What chip does Groq use and how fast is it?")
rag_query("Who founded Groq?")
rag_query("Is the Groq API compatible with OpenAI code?")
# Out:
# Loading embedding model...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Indexed 10 documents
# Q: What chip does Groq use and how fast is it?
# A: Groq uses a custom chip called the LPU (Language Processing Unit), which achieves speeds of 500+ tokens per second on LLaMA models.
# ------------------------------------------------------------
# Q: Who founded Groq?
# A: Ex-Google TPU engineers.
# ------------------------------------------------------------
# Q: Is the Groq API compatible with OpenAI code?
# A: Yes, it is compatible with the OpenAI SDK using a base_url swap.
# ------------------------------------------------------------
# 'Yes, it is compatible with the OpenAI SDK using a base_url swap.'

# %% [markdown]
# ---
# ## Example 12 - Async Batch Processing
#
# Process many prompts concurrently using asyncio — dramatically faster than sequential calls.

# %%
import asyncio
import time
from groq import AsyncGroq

async_client = AsyncGroq(api_key=GROQ_API_KEY)

prompts = [
    "Explain black holes in one sentence.",
    "What is the capital of Australia?",
    "Give me a fun fact about octopuses.",
    "What does REST stand for in APIs?",
    "Name the three laws of thermodynamics briefly.",
    "Who wrote 1984 and in what year?",
    "What is the difference between TCP and UDP?",
    "Explain photosynthesis in one sentence.",
]


async def fetch_one(prompt, idx):
    response = await async_client.chat.completions.create(
        model=MODELS['fast'],
        messages=[{"role": "user", "content": prompt}],
        max_tokens=80
    )
    return {"idx": idx, "prompt": prompt, "answer": response.choices[0].message.content.strip()}


async def batch_process(prompts):
    tasks = [fetch_one(p, i) for i, p in enumerate(prompts)]
    return await asyncio.gather(*tasks)


print(f"Processing {len(prompts)} prompts...\n")

# Sequential timing
t0 = time.time()
for p in prompts:
    client.chat.completions.create(
        model=MODELS['fast'], messages=[{"role": "user", "content": p}], max_tokens=80
    )
seq_time = time.time() - t0

# Async timing
t0 = time.time()
async_results = await batch_process(prompts)  # top-level await works in Colab
async_time = time.time() - t0

print("Results:\n")
for r in async_results:
    print(f"  Q: {r['prompt']}")
    print(f"  A: {r['answer']}\n")

print("=" * 60)
print(f"Sequential : {seq_time:.2f}s")
print(f"Async      : {async_time:.2f}s")
print(f"Speedup    : {seq_time / async_time:.1f}x faster")
# Out:
# Processing 8 prompts...
#
# Results:
#
#   Q: Explain black holes in one sentence.
#   A: A black hole is a region in space where the gravitational pull is so strong that nothing, including light, can escape once it crosses a point called the event horizon, making it invisible and inaccessible to the outside universe.
#
#   Q: What is the capital of Australia?
#   A: The capital of Australia is Canberra.
#
#   Q: Give me a fun fact about octopuses.
#   A: Octopuses are incredibly intelligent creatures, but one of their most fascinating features is their ability to lose an arm on purpose, a behavior known as autotomy. This allows them to escape from predators. The detached arm continues to writhe and move, distracting the predator while the octopus slips away to safety. It can even regrow a new arm later. This unique feature not only protects the oct
#
#   Q: What does REST stand for in APIs?
#   A: REST stands for Representational State of Resource. It is an architecture style for designing networked applications, particularly APIs (Application Programming Interfaces). REST is commonly used for building web services, as it simplifies interaction between systems by standardizing the way data is requested, exchanged, and modified.
#
# Here are the key components of REST:
#
# 1. **Resource**: This refers to the data or service being accessed.
#
#   Q: Name the three laws of thermodynamics briefly.
#   A: The three laws of thermodynamics are:
#
# 1. **Zeroth Law of Thermodynamics**: If two systems are in thermal equilibrium with a third system, then they are also in thermal equilibrium with each other. This law allows us to define a temperature scale.
#
# 2. **First Law of Thermodynamics (Conservation of Energy)**: The total energy of an isolated system remains constant over time. Energy can
#
#   Q: Who wrote 1984 and in what year?
#   A: The book "1984" was written by George Orwell. It was first published on June 8, 1949. George Orwell, whose real name was Eric Arthur Blair, was a British author, essayist, and critic best known for his dystopian novel "1984," as well as "Animal Farm."
#
#   Q: What is the difference between TCP and UDP?
#   A: TCP (Transmission Control Protocol) and UDP (User Datagram Protocol) are both transport-layer protocols used for communication between devices on a network. The key differences between them are:
#
# 1. **Connection-oriented vs Connectionless**:
#    - **TCP**: Establishes a connection between the sender and receiver before data is sent. This connection is verified through a 3-way handshake (SYN, SYN-ACK
#
#   Q: Explain photosynthesis in one sentence.
#   A: Photosynthesis is the process by which plants, algae, and some bacteria convert light energy from the sun into chemical energy in the form of glucose, releasing oxygen as a byproduct.
#
# ============================================================
# Sequential : 1.23s
# Async      : 0.31s
# Speedup    : 4.0x faster

# %% [markdown]
# ---
# ## Example 13 - Prompt Chaining & Summarization
#
# Chain multiple LLM calls — each step's output feeds the next. Perfect for document processing pipelines.

# %%
def llm(system, user, model=None, max_tokens=512):
    model = model or MODELS['balanced']
    r = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": system},
            {"role": "user",   "content": user}
        ],
        max_tokens=max_tokens
    )
    return r.choices[0].message.content.strip()


long_article = """
The James Webb Space Telescope (JWST), launched on December 25, 2021, represents the most
powerful space telescope ever built. A product of international collaboration between NASA,
ESA, and CSA, JWST operates at the second Lagrange point (L2), approximately 1.5 million
kilometers from Earth. Its 6.5-meter primary mirror comprised of 18 hexagonal gold-coated
beryllium segments gathers 6x more light than the Hubble Space Telescope.

JWST is engineered to observe the universe primarily in the infrared spectrum, allowing it
to peer through cosmic dust clouds and detect light from the earliest galaxies, formed just
a few hundred million years after the Big Bang. Its instruments include NIRCam, NIRSpec,
MIRI, and FGS/NIRISS.

Early science results have been extraordinary. JWST captured the deepest infrared image of
the universe ever taken, revealing thousands of galaxies in extraordinary detail. It also
produced detailed atmospheric spectra of exoplanets, including detection of carbon dioxide
in the atmosphere of WASP-39b. The telescope has also revealed new details about star
formation in the Carina Nebula.

With a design lifetime of 10 years, with fuel reserves potentially extending to 20 years,
JWST promises decades of groundbreaking astronomical discoveries.
"""

print("Running 4-step prompt chain...\n")
print("-" * 60)

# Step 1: Extract key facts
facts = llm(
    system="Extract the 5 most important factual claims from the text as a numbered list. Facts only.",
    user=long_article
)
print("STEP 1 - Key Facts:")
print(facts)
print()

# Step 2: Simplify for kids
simplified = llm(
    system="Rewrite these facts so a 12-year-old can understand them. Keep all 5 points but use simple language.",
    user=facts
)
print("STEP 2 - Simplified for kids:")
print(simplified)
print()

# Step 3: Tweet thread
tweets = llm(
    system="Convert these 5 facts into a Twitter/X thread. Each tweet max 280 chars. Number them 1/5 through 5/5. Add relevant emojis.",
    user=simplified,
    max_tokens=400
)
print("STEP 3 - Tweet Thread:")
print(tweets)
print()

# Step 4: TL;DR
tldr = llm(
    system="Write a single sentence TL;DR of the entire thread. Maximum 25 words.",
    user=tweets,
    max_tokens=60
)
print("STEP 4 - TL;DR:")
print(tldr)
# Out:
# Running 4-step prompt chain...
#
# ------------------------------------------------------------
# STEP 1 - Key Facts:
# Here are the 5 most important factual claims from the text:
#
# 1. The James Webb Space Telescope (JWST) was launched on December 25, 2021.
# 2. The JWST operates at the second Lagrange point (L2), approximately 1.5 million kilometers from Earth.
# 3. The JWST's primary mirror is 6.5 meters in diameter and is comprised of 18 hexagonal gold-coated beryllium segments.
# 4. The JWST is designed to observe the universe primarily in the infrared spectrum.
# 5. The JWST has a design lifetime of 10 years, with potential fuel reserves extending to 20 years.
#
# STEP 2 - Simplified for kids:
# Here are the facts rewritten for a 12-year-old:
#
# 1. The James Webb Space Telescope was sent into space on Christmas Day in 2021.
# 2. The telescope is really far away from Earth - about 1.5 million kilometers away. It stays in a special spot where the Sun and Earth's gravity balance out.
# 3. The main mirror of the telescope is really big - 6.5 meters across. It's made up of 18 special pieces that are shaped like hexagons and are covered in a thin layer of gold.
# 4. The James Webb Space Telescope is special because it can see things in the universe that are too far away or too hidden to see with our eyes. It does this by looking at a kind of light called infrared, which is like a special kind of heat.
# 5. The telescope is designed to keep working for at least 10 years, but it might be able to keep going for up to 20 years if it uses its fuel wisely. That's a long time to be exploring the universe!
#
# STEP 3 - Tweet Thread:
# 1/5 🚀🎄 The James Webb Space Telescope launched on Christmas Day 2021! It's been exploring the universe for us since then 🌠
#
# 2/5 🌎🛰️ It's 1.5 million km away from Earth, in a special spot where Sun & Earth's gravity balance out. Mind blown, right? 🤯
#
# 3/5 🔍💫 The main mirror is 6.5m across, made of 18 hexagonal pieces covered in a thin gold layer. That's one cool mirror! 😎
#
# 4/5 🔦🔍 It sees things we can't with our eyes by looking at infrared light, like a special kind of heat. It's uncovering secrets of the universe! 🌟
#
# 5/5 🕰️🚀 Designed to work for 10+ years, maybe even 20 if it uses fuel wisely. That's a long time to explore the universe and make new discoveries! 🚀💫
#
# STEP 4 - TL;DR:
# James Webb Space Telescope explores universe since 2021 launch.

# %% [markdown]
# ---
# ## Example 14 - Interactive Chatbot UI (ipywidgets)
#
# A real chat interface with message history, send button, and clear button — all inside Colab.

# %%
import ipywidgets as widgets
from IPython.display import display, HTML, clear_output

chat_history = []
SYSTEM_PROMPT = "You are a helpful, friendly assistant. Keep responses concise."


def get_response(user_msg):
    chat_history.append({"role": "user", "content": user_msg})
    messages = [{"role": "system", "content": SYSTEM_PROMPT}] + chat_history
    r = client.chat.completions.create(
        model=MODELS['balanced'], messages=messages, max_tokens=512
    )
    reply = r.choices[0].message.content
    chat_history.append({"role": "assistant", "content": reply})
    return reply


def render_chat():
    html = '<div style="font-family:sans-serif; max-width:700px;">'
    for msg in chat_history:
        if msg["role"] == "user":
            html += f'''
            <div style="text-align:right; margin:8px 0;">
              <span style="background:#0084ff; color:white; padding:8px 14px;
                           border-radius:18px 18px 4px 18px; display:inline-block;
                           max-width:70%; word-wrap:break-word;">{msg["content"]}</span>
            </div>'''
        else:
            html += f'''
            <div style="text-align:left; margin:8px 0;">
              <span style="background:#e9e9eb; color:#111; padding:8px 14px;
                           border-radius:18px 18px 18px 4px; display:inline-block;
                           max-width:70%; word-wrap:break-word;">{msg["content"]}</span>
            </div>'''
    html += '</div>'
    return html


chat_output = widgets.Output(
    layout=widgets.Layout(height='380px', overflow_y='auto',
                          border='1px solid #ddd', padding='10px',
                          border_radius='8px')
)
text_input = widgets.Text(
    placeholder='Type a message...',
    layout=widgets.Layout(width='80%')
)
send_btn  = widgets.Button(description='Send', button_style='primary',
                            layout=widgets.Layout(width='18%'))
clear_btn = widgets.Button(description='Clear', button_style='warning',
                            layout=widgets.Layout(width='100%', margin='5px 0'))
status    = widgets.Label(value='Ready')


def on_send(b):
    user_msg = text_input.value.strip()
    if not user_msg:
        return
    text_input.value = ''
    status.value = 'Thinking...'
    send_btn.disabled = True
    get_response(user_msg)
    with chat_output:
        clear_output(wait=True)
        display(HTML(render_chat()))
    status.value = f'{len(chat_history)//2} exchanges'
    send_btn.disabled = False


def on_clear(b):
    chat_history.clear()
    with chat_output:
        clear_output()
    status.value = 'Cleared'


send_btn.on_click(on_send)
clear_btn.on_click(on_clear)

display(widgets.VBox([
    widgets.HTML('<h3 style="font-family:sans-serif">Groq Chatbot</h3>'),
    chat_output,
    widgets.HBox([text_input, send_btn]),
    clear_btn,
    status
]))
# Out:
# VBox(children=(HTML(value='<h3 style="font-family:sans-serif">Groq Chatbot</h3>'), Output(layout=Layout(border…

# %% [markdown]
# ---
# ## Example 15 - CSV / Data Analysis Agent
#
# Ask plain-English questions about a CSV. The agent generates pandas code, executes it, and explains the result.

# %%
import pandas as pd
import io
import traceback

# Sample dataset - swap this for your own CSV!
# df = pd.read_csv('your_file.csv')
sample_csv = """date,product,region,units_sold,revenue,return_rate
2024-01-05,Laptop,North,120,144000,0.02
2024-01-05,Laptop,South,85,102000,0.03
2024-01-12,Phone,North,310,155000,0.01
2024-01-12,Phone,South,270,135000,0.02
2024-02-03,Tablet,North,90,63000,0.04
2024-02-03,Tablet,South,110,77000,0.02
2024-02-14,Laptop,North,150,180000,0.01
2024-02-14,Laptop,South,95,114000,0.03
2024-03-01,Phone,North,400,200000,0.02
2024-03-01,Phone,South,350,175000,0.01
2024-03-15,Tablet,North,80,56000,0.05
2024-03-15,Tablet,South,130,91000,0.02
"""

df = pd.read_csv(io.StringIO(sample_csv))
print("Dataset loaded:")
print(df.to_string(index=False))
# Out:
# Dataset loaded:
#       date product region  units_sold  revenue  return_rate
# 2024-01-05  Laptop  North         120   144000         0.02
# 2024-01-05  Laptop  South          85   102000         0.03
# 2024-01-12   Phone  North         310   155000         0.01
# 2024-01-12   Phone  South         270   135000         0.02
# 2024-02-03  Tablet  North          90    63000         0.04
# 2024-02-03  Tablet  South         110    77000         0.02
# 2024-02-14  Laptop  North         150   180000         0.01
# 2024-02-14  Laptop  South          95   114000         0.03
# 2024-03-01   Phone  North         400   200000         0.02
# 2024-03-01   Phone  South         350   175000         0.01
# 2024-03-15  Tablet  North          80    56000         0.05
# 2024-03-15  Tablet  South         130    91000         0.02

# %%
def data_analyst(question, dataframe):
    schema = f"""DataFrame name: df
Columns: {list(dataframe.columns)}
Dtypes: {dataframe.dtypes.to_dict()}
Shape: {dataframe.shape}
Sample rows:
{dataframe.head(3).to_string(index=False)}"""

    # Step 1: Generate code
    code_response = client.chat.completions.create(
        model=MODELS['balanced'],
        messages=[
            {
                "role": "system",
                "content": (
                    "You are a data analysis expert. Given a DataFrame schema and a question, "
                    "write a Python pandas expression to answer it. "
                    "Return ONLY the Python code (no imports, no markdown, no explanation). "
                    "Store the final result in a variable called result."
                )
            },
            {"role": "user", "content": f"Schema:\n{schema}\n\nQuestion: {question}"}
        ],
        temperature=0,
        max_tokens=256
    )

    code = code_response.choices[0].message.content.strip()
    code = code.replace('```python', '').replace('```', '').strip()
    print(f"  Code: {code}")

    # Step 2: Execute code
    exec_locals = {"df": dataframe, "pd": pd}
    try:
        exec(code, {"__builtins__": {"print": print, "round": round, "len": len, "int": int, "float": float, "str": str}}, exec_locals)
        raw_result = exec_locals.get("result", "No result variable found")
    except Exception:
        return f"Execution error: {traceback.format_exc()}"

    # Step 3: Explain result in plain English
    explanation = client.chat.completions.create(
        model=MODELS['fast'],
        messages=[
            {"role": "system", "content": "Convert this data result into a clear, concise plain-English answer. One or two sentences max."},
            {"role": "user", "content": f"Question: {question}\nResult: {raw_result}"}
        ],
        max_tokens=100
    )
    return explanation.choices[0].message.content.strip()


questions = [
    "What is the total revenue across all products and regions?",
    "Which product has the highest average return rate?",
    "What is the best-performing region by total units sold?",
    "Which month had the highest total revenue?",
    "Show me total revenue broken down by product.",
]

for q in questions:
    print(f"\nQ: {q}")
    answer = data_analyst(q, df)
    print(f"A: {answer}")
    print("-" * 60)
# Out:
# Q: What is the total revenue across all products and regions?
#   Code: result = df['revenue'].sum()
# A: The total revenue across all products and regions is $1,492,000.
# ------------------------------------------------------------
#
# Q: Which product has the highest average return rate?
#   Code: result = df.loc[df.groupby('product')['return_rate'].idxmax()]
# A: The Tablet product has the highest average return rate with 0.05.
# ------------------------------------------------------------
#
# Q: What is the best-performing region by total units sold?
#   Code: result = df.groupby('region')['units_sold'].sum().idxmax()
# A: The North region has the best performance by total units sold.
# ------------------------------------------------------------
#
# Q: Which month had the highest total revenue?
#   Code: df['date'] = pd.to_datetime(df['date'])
# df['month'] = df['date'].dt.to_period('M')
# result = df.groupby('month')['revenue'].sum().idxmax()
# A: January 2024 had the highest total revenue.
# ------------------------------------------------------------
#
# Q: Show me total revenue broken down by product.
#   Code: result = df.groupby('product')['revenue'].sum().reset_index()
# A: The company's total revenue is $1,492,000. The breakdown by product is: Laptops at $540,000, Phones at $665,000, and Tablets at $287,000.
# ------------------------------------------------------------

# %% [markdown]
# ---
# ## Quick Reference
#
# | Concept | Key param / method |
# |---|---|
# | Pick a model | `model=` |
# | Control creativity | `temperature=` (0 = deterministic, 1 = creative) |
# | Limit output | `max_tokens=` |
# | Force JSON output | `response_format={"type": "json_object"}` |
# | Stream tokens | `client.chat.completions.stream(...)` |
# | Async / concurrent | `AsyncGroq` + `asyncio.gather(...)` |
# | Use tools | `tools=[...]`, `tool_choice="auto"` |
# | OpenAI compat | `base_url="https://api.groq.com/openai/v1"` |
#
# **Useful links:**
# - [Groq Docs](https://console.groq.com/docs)
# - [API Keys](https://console.groq.com/keys)
# - [Model List](https://console.groq.com/docs/models)
# - [Discord Community](https://discord.gg/groq)
